# %% [markdown]
# # Simple plots to visualise audio input data

# %%
import numpy as np
# %matplotlib inline
import pylab as plt

#
#load audio data
#
data = np.loadtxt('../samples/sample_sines.txt')
samples = data[:,None]
print(samples)
# Out:
# [[ 0.      ]
#  [ 0.      ]
#  [ 0.      ]
#  ...
#  [-0.031282]
#  [-0.031292]
#  [-0.031196]]

# %%
#
# load FFT data
#
data = np.loadtxt('../samples/output.txt')
fft = []
n_frames = len(data)/513

for i in (int)n_frames:
    fft.append(data[i*513:(i+1)*513])
    
print(frames)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5db398441fa2> in <module>()
#       6 n_frames = len(data)/513
#       7
# ----> 8 for i in n_frames:
#       9     fft.append(data[i*513:(i+1)*513])
#      10
#
# TypeError: 'float' object is not iterable

# %%
plt.plot(samples[400000:401000])

# %%
plt.plot(samples[1000000:1001000])
