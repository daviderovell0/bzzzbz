# %% [markdown]
# # Simple plots to visualise audio input data

# %%
import numpy as np
# %matplotlib inline
import pylab as plt

#load data
data = np.loadtxt('../mic_samples.txt')
samples = data[:,None]
print(samples)
# Out:
# [[0.      ]
#  [0.      ]
#  [0.      ]
#  ...
#  [0.007359]
#  [0.005623]
#  [0.005132]]

# %%
plt.plot(samples[280000:300000])

# %%
plt.plot(samples[281000:285000])
